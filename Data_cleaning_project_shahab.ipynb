# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import random

# %%
filepath='C:/Users/shaha/Desktop/Springboard/DataScience_Capstone2/Dataset_II/Hotel booking/hotel_bookings.csv'
dfi=pd.read_csv(filepath)

# %%
dfi
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
print(dfi.shape)
dfi.columns
# Out:
# (119390, 32)
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
dfi.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
dfi.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
dfi.isna()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of company doesn't have a name
dfi[dfi['company'].isna()==True]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of company has a name
dfi[dfi['company'].isna()==False]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 218     Resort Hotel            1          1               2015
# 219     Resort Hotel            1          1               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# ...              ...          ...        ...                ...
# 119119    City Hotel            0         40               2017
# 119122    City Hotel            0         40               2017
# 119123    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 218                  July                        28
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of agent doesn't have a name
dfi[dfi['agent'].isna()==True]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 6       Resort Hotel            0          0               2015
# 18      Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119124    City Hotel            0          0               2017
# 119151    City Hotel            0          0               2017
# 119166    City Hotel            0          0               2017
# 119215    City Hotel            0          2               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#It is much better to remove the columns of company and agent
dfi=dfi.drop(["agent","company"], axis=1)

# %%
dfi.shape
# Out:
# (119390, 30)

# %%
dfi[dfi['is_canceled'].isna()]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 30 columns]

# %%
dfi[dfi['is_canceled'].isna()==True]['is_canceled']
# Out:
# Series([], Name: is_canceled, dtype: int64)

# %%
#This block is utilized to find NAN values for each column
for j in dfi.columns:
    print('***column of ',j,'***')
    print(dfi[dfi[j].isna()==True][j])
    print('-----------------------------------------')
# Out:
# ***column of  hotel ***
# Series([], Name: hotel, dtype: object)
# -----------------------------------------
# ***column of  is_canceled ***
# Series([], Name: is_canceled, dtype: int64)
# -----------------------------------------
# ***column of  lead_time ***
# Series([], Name: lead_time, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_year ***
# Series([], Name: arrival_date_year, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_month ***
# Series([], Name: arrival_date_month, dtype: object)
# -----------------------------------------
# ***column of  arrival_date_week_number ***
# Series([], Name: arrival_date_week_number, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_day_of_month ***
# Series([], Name: arrival_date_day_of_month, dtype: int64)
# -----------------------------------------
# ***column of  stays_in_weekend_nights ***
# ...

# %%
dfi.loc[40600,'children']=0
dfi.loc[40667,'children']=0
dfi.loc[40679,'children']=0
dfi.loc[41160,'children']=0

# %%
dfi[dfi['children'].isna()==True]['children']
# Out:
# Series([], Name: children, dtype: float64)

# %%
dfi[dfi['country'].isna()==True]['country']
# Out:
# 30        NaN
# 4127      NaN
# 7092      NaN
# 7860      NaN
# 8779      NaN
#          ...
# 65908     NaN
# 65909     NaN
# 65910     NaN
# 80830     NaN
# 101488    NaN
# Name: country, Length: 488, dtype: object

# %%
dfi_cleaned=dfi[dfi['country'].isna()==False]

# %%
for j in dfi_cleaned.columns:
    print('***column of ',j,'***')
    print(dfi_cleaned[dfi_cleaned[j].isna()==True][j])
    print('-----------------------------------------')
# Out:
# ***column of  hotel ***
# Series([], Name: hotel, dtype: object)
# -----------------------------------------
# ***column of  is_canceled ***
# Series([], Name: is_canceled, dtype: int64)
# -----------------------------------------
# ***column of  lead_time ***
# Series([], Name: lead_time, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_year ***
# Series([], Name: arrival_date_year, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_month ***
# Series([], Name: arrival_date_month, dtype: object)
# -----------------------------------------
# ***column of  arrival_date_week_number ***
# Series([], Name: arrival_date_week_number, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_day_of_month ***
# Series([], Name: arrival_date_day_of_month, dtype: int64)
# -----------------------------------------
# ***column of  stays_in_weekend_nights ***
# ...

# %%
df=dfi_cleaned

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
plt.hist(df['is_canceled'])
plt.xlabel('0=Reservation             1=Cancelation')
plt.ylabel('number of reservation or cancelation')
plt.show()

# %%
x=df[df['is_canceled']==0]['arrival_date_month']
y=df[df['is_canceled']==0]['is_canceled']
plt.hist(x)
plt.xlabel('Month of reservation')
plt.ylabel('Number of reservation')
plt.xticks(rotation=45)
plt.show()

# %%
x=df[df['is_canceled']==0]['stays_in_weekend_nights']
plt.hist(x,bins=20)
plt.xlabel('Staying in weekend nights')
plt.ylabel('Number of reservation')
#plt.xticks(rotation=45)
plt.show()

# %%
x=df[df['is_canceled']==0]['stays_in_week_nights']
y=df[df['is_canceled']==0]['stays_in_weekend_nights']
plt.scatter(x,y)
plt.xlabel('stays_in_week_nights')
plt.ylabel('stays_in_weekend_nights')
#plt.xticks(rotation=45)
plt.show()
